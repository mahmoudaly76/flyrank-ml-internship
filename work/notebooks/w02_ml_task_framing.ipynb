# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahmoudaly76/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Lane: Content Decay Prediction
# Task Type: Scoring
# Explanation: Although predicting if a page is declining seems like a binary Classification task (Yes/No), we need to frame it as a Scoring task. This allows us to rank the pages by their likelihood of decay, so we can prioritize them based on the limited capacity of our content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target: Whether a page's traffic is actively decaying (e.g., trend_direction == 'down').
# Proxy: Since we need an ordered list, our proxy is the predicted probability (from 0 to 1) that a page belongs to the declining class, based on historical signals like age and impressions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success Metric: Precision@50
# Why: Overall accuracy doesn't matter if we can only afford to update 50 pages a month. Precision@50 tells us exactly how many of our top 50 flagged pages were actually decaying. This directly ties model performance to business ROI.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

# Load the starter data directly from the raw GitHub link
url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# Display the unit of analysis
print("Unit of Analysis: 1 Row = 1 Web Page")
print(f"Total rows (pages) in our dataset: {df.shape[0]:,}")

# Sketching what the target column looks like alongside the data
df[['impressions_90d', 'days_since_last_update', 'ctr', 'trend_direction']].head()
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Unit of Analysis: 1 Row = 1 Web Page
# Total rows (pages) in our dataset: 30,000
#    impressions_90d  days_since_last_update   ctr trend_direction
# 0             3803                      20  0.76            down
# 1            15320                      25  0.05            down
# 2            12581                      20  0.09            down
# 3            11751                      22  0.49          stable
# 4            19140                      14  0.13            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Why ML wins: A fixed human rule (like "flag if page age > 180 days and impressions > 500") is too rigid and only captures a small fraction of real problems (e.g., 24% precision). An ML model looks at non-linear relationships across multiple variables simultaneously (age, CTR, impressions) to find subtle patterns that a simple if/else statement would completely miss, boosting our precision significantly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# All checks completed. The problem is mapped to the ML loop with a clear task type, target, and business-aligned success metric. The unit of analysis is proven with real data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
